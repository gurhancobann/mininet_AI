# %%
import pandas as pd
import numpy as num_paths
import matplotlib.pyplot as psnrResault
import seaborn as sns
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")
from matplotlib import pyplot as plt
# Out:
# /home/gurhancoban/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("data16072024.csv")

# %%
df=pd.DataFrame(df)
df.head()
# Out:
#   host    avgRTT  packetLoss  latency  hopCount  bandwidth       psnr  \
# 0   h1  1263.237         0.0       75         4   10000000  31.961797
# 1   h2   927.248         0.0       87         4   10000000  24.008528
# 2   h3  1430.356         0.0      101         5   10000000  21.008091
# 3   h4  1460.157         0.0       63         3   10000000  18.716508
# 4   h5       NaN       100.0       63         4   10000000  16.372364
#
#    ssim_first  ssim_second    kaynak  kayitboyut     kayip  kayip_orani  type  \
# 0    0.985717    18.451736  67209812    67371008   -161196    -0.239840     1
# 1    0.945897    12.667787  67209812    66060288   1149524     1.710351     1
# 2    0.886787     9.461035  67209812    62390272   4819540     7.170887     1
# 3    0.827955     7.643567  67209812    56098816  11110996    16.531806     1
# 4    0.792841     6.836966  67209812    51380224  15829588    23.552496     1
#
#   server
# 0    h10
# 1    h10
# 2    h10
# 3    h10
# 4    h10

# %%
df["kayitboyut"]=df["kayitboyut"]-161196

# %%
df["kayip"]=df["kaynak"]-df["kayitboyut"]
df["kayip_orani"]=(df["kayip"]/df["kaynak"])*100
df.head()
# Out:
#   host    avgRTT  packetLoss  latency  hopCount  bandwidth       psnr  \
# 0   h1  1263.237         0.0       75         4   10000000  31.961797
# 1   h2   927.248         0.0       87         4   10000000  24.008528
# 2   h3  1430.356         0.0      101         5   10000000  21.008091
# 3   h4  1460.157         0.0       63         3   10000000  18.716508
# 4   h5       NaN       100.0       63         4   10000000  16.372364
#
#    ssim_first  ssim_second    kaynak  kayitboyut     kayip  kayip_orani  type  \
# 0    0.985717    18.451736  67209812    67209812         0     0.000000     1
# 1    0.945897    12.667787  67209812    65899092   1310720     1.950191     1
# 2    0.886787     9.461035  67209812    62229076   4980736     7.410727     1
# 3    0.827955     7.643567  67209812    55937620  11272192    16.771646     1
# 4    0.792841     6.836966  67209812    51219028  15990784    23.792336     1
#
#   server
# 0    h10
# 1    h10
# 2    h10
# 3    h10
# 4    h10

# %%
df.describe().T
# Out:
#              count          mean           std           min           25%  \
# avgRTT       356.0  5.084837e+02  4.720382e+02  1.529010e+02  2.519055e+02
# packetLoss   360.0  1.820988e+00  1.215084e+01  0.000000e+00  0.000000e+00
# latency      360.0  6.320556e+01  3.240451e+01  0.000000e+00  4.500000e+01
# hopCount     360.0  2.850000e+00  1.050136e+00  1.000000e+00  2.000000e+00
# bandwidth    360.0  1.000000e+07  0.000000e+00  1.000000e+07  1.000000e+07
# psnr         360.0  2.481996e+01  6.615808e+00  9.057327e+00  1.844287e+01
# ssim_first   360.0  9.088615e-01  1.074401e-01  3.901070e-01  8.308920e-01
# ssim_second  360.0  1.369672e+01  5.677780e+00  2.147460e+00  7.718365e+00
# kaynak       360.0  6.720981e+07  0.000000e+00  6.720981e+07  6.720981e+07
# kayitboyut   360.0  5.850954e+07  1.018665e+07  2.722388e+06  5.619976e+07
# kayip        360.0  8.700268e+06  1.018665e+07  0.000000e+00  1.310720e+06
# ...

# %%
df_S1=df[df["type"]==1]
df_S1
# Out:
#     host    avgRTT  packetLoss  latency  hopCount  bandwidth       psnr  \
# 0     h1  1263.237         0.0       75         4   10000000  31.961797
# 1     h2   927.248         0.0       87         4   10000000  24.008528
# 2     h3  1430.356         0.0      101         5   10000000  21.008091
# 3     h4  1460.157         0.0       63         3   10000000  18.716508
# 4     h5       NaN       100.0       63         4   10000000  16.372364
# ..   ...       ...         ...      ...       ...        ...        ...
# 115   h2   262.524         0.0       75         3   10000000  16.222557
# 116   h1   297.081         0.0       65         4   10000000  17.052092
# 117   h3   208.337         0.0       78         2   10000000  16.095782
# 118   h4   280.969         0.0       56         3   10000000  16.550696
# 119   h6   158.587         0.0       28         1   10000000  15.588232
#
#      ssim_first  ssim_second    kaynak  kayitboyut     kayip  kayip_orani  \
# ...

# %%
df_S2=df[df["type"]==2]
df_S2
# Out:
#     host   avgRTT  packetLoss  latency  hopCount  bandwidth       psnr  \
# 120   h1  252.819         0.0        0         3   10000000  31.744089
# 121   h2  413.499         0.0       30         5   10000000  35.199215
# 122   h3  221.382         0.0        0         2   10000000  32.454371
# 123   h4      NaN       100.0       51         5   10000000  33.735441
# 124   h5  206.776         0.0        0         2   10000000  28.857236
# ..   ...      ...         ...      ...       ...        ...        ...
# 235   h1  326.249         0.0       79         4   10000000  26.120255
# 236   h2  325.484         0.0       66         4   10000000  23.589518
# 237   h3  234.255         0.0       47         2   10000000  25.888742
# 238   h4  279.789         0.0       67         3   10000000  21.113936
# 239   h6  184.977         0.0       19         1   10000000  21.313627
#
#      ssim_first  ssim_second    kaynak  kayitboyut    kayip  kayip_orani  \
# ...

# %%
df_S3=df[df["type"]==3]
df_S3
# Out:
#     host   avgRTT  packetLoss  latency  hopCount  bandwidth       psnr  \
# 240   h1  307.043         0.0      102         4   10000000  33.233620
# 241   h2  344.930         0.0       57         3   10000000  34.820163
# 242   h3  234.543         0.0       42         2   10000000  31.698655
# 243   h4  443.503         0.0       71         3   10000000  28.379155
# 244   h5  727.099         0.0      105         4   10000000  30.289373
# ..   ...      ...         ...      ...       ...        ...        ...
# 355   h7  367.810         0.0      101         4   10000000  25.966529
# 356   h8  297.589         0.0       65         3   10000000  21.789075
# 357   h9  319.824         0.0       63         3   10000000  27.157776
# 358  h11  169.640         0.0       20         1   10000000  26.111773
# 359   h6  189.760         0.0       25         1   10000000  21.515200
#
#      ssim_first  ssim_second    kaynak  kayitboyut    kayip  kayip_orani  \
# ...

# %%
df_S1["ssim_first"].mean()
# Out:
# 0.7930526416666666

# %%
df_S2["ssim_first"].mean()
# Out:
# 0.96563935

# %%
df_S3["ssim_first"].mean()
# Out:
# 0.967892575

# %%
df_S1_h6=df_S1[df_S1["host"]=="h6"]
df_S1_h6["ssim_first"].mean()
# Out:
# 0.6891928999999999

# %%
df_S2_h6=df_S2[df_S2["host"]=="h6"]
df_S2_h6["ssim_first"].mean()
# Out:
# 0.9418309

# %%
df_S3_h6=df_S3[df_S3["host"]=="h6"]
df_S3_h6["ssim_first"].mean()
# Out:
# 0.9512495

# %%
df_S1["kayip"].mean()/(1024*1024)
# Out:
# 17.433333333333334

# %%
df_S2["kayip"].mean()/(1024*1024)
# Out:
# 3.6041666666666665

# %%
df_S3["kayip"].mean()/(1024*1024)
# Out:
# 3.8541666666666665

# %%
df_S1["latency"].mean()
# Out:
# 54.925

# %%
df_S2["latency"].mean()
# Out:
# 62.8

# %%
df_S3["latency"].mean()
# Out:
# 71.89166666666667

# %%
df_S1.describe().T
# Out:
#              count          mean           std           min           25%  \
# avgRTT       119.0  7.354098e+02  4.962656e+02  1.529010e+02  2.602110e+02
# packetLoss   120.0  8.333333e-01  9.128709e+00  0.000000e+00  0.000000e+00
# latency      120.0  5.492500e+01  2.715909e+01  0.000000e+00  4.100000e+01
# hopCount     120.0  2.900000e+00  1.048408e+00  1.000000e+00  2.000000e+00
# bandwidth    120.0  1.000000e+07  0.000000e+00  1.000000e+07  1.000000e+07
# psnr         120.0  1.865756e+01  4.953213e+00  1.504465e+01  1.592645e+01
# ssim_first   120.0  7.930526e-01  9.444236e-02  6.828440e-01  7.206497e-01
# ssim_second  120.0  7.952932e+00  4.115267e+00  4.987273e+00  5.538516e+00
# kaynak       120.0  6.720981e+07  0.000000e+00  6.720981e+07  6.720981e+07
# kayitboyut   120.0  4.892964e+07  1.110243e+07  3.444181e+07  3.994684e+07
# kayip        120.0  1.828017e+07  1.110243e+07  0.000000e+00  9.568256e+06
# ...

# %%
df_S2.describe().T
# Out:
#              count          mean           std           min           25%  \
# avgRTT       118.0  4.636631e+02  5.693920e+02  1.604820e+02  2.568805e+02
# packetLoss   120.0  3.796296e+00  1.651791e+01  0.000000e+00  0.000000e+00
# latency      120.0  6.280000e+01  3.779836e+01  0.000000e+00  3.900000e+01
# hopCount     120.0  2.891667e+00  1.136084e+00  1.000000e+00  2.000000e+00
# bandwidth    120.0  1.000000e+07  0.000000e+00  1.000000e+07  1.000000e+07
# psnr         120.0  2.749060e+01  4.971994e+00  9.057327e+00  2.504148e+01
# ssim_first   120.0  9.656394e-01  4.871184e-02  4.797230e-01  9.613367e-01
# ssim_second  120.0  1.627137e+01  3.805417e+00  2.837656e+00  1.412703e+01
# kaynak       120.0  6.720981e+07  0.000000e+00  6.720981e+07  6.720981e+07
# kayitboyut   120.0  6.343057e+07  3.171066e+06  5.724834e+07  6.013192e+07
# kayip        120.0  3.779243e+06  3.171066e+06  0.000000e+00  2.621440e+05
# ...

# %%
df_S3.describe().T
# Out:
#              count          mean           std           min           25%  \
# avgRTT       119.0  3.260015e+02  1.228267e+02  1.575560e+02  2.335945e+02
# packetLoss   120.0  8.333333e-01  9.128709e+00  0.000000e+00  0.000000e+00
# latency      120.0  7.189167e+01  2.925886e+01  2.000000e+01  5.100000e+01
# hopCount     120.0  2.758333e+00  9.614051e-01  1.000000e+00  2.000000e+00
# bandwidth    120.0  1.000000e+07  0.000000e+00  1.000000e+07  1.000000e+07
# psnr         120.0  2.831172e+01  5.000595e+00  1.278486e+01  2.554090e+01
# ssim_first   120.0  9.678926e-01  5.694557e-02  3.901070e-01  9.643168e-01
# ssim_second  120.0  1.686587e+01  3.969381e+00  2.147460e+00  1.447538e+01
# kaynak       120.0  6.720981e+07  0.000000e+00  6.720981e+07  6.720981e+07
# kayitboyut   120.0  6.316843e+07  6.393303e+06  2.722388e+06  6.013192e+07
# kayip        120.0  4.041387e+06  6.393303e+06  0.000000e+00  2.621440e+05
# ...

# %%
s1h6h10=df_S1_h6[df_S1_h6["server"]=="h10"]
s1h6h14=df_S1_h6[df_S1_h6["server"]=="h14"]

print(f'h6\'nın h10\'a gittiğindeki ssim{s1h6h10["ssim_first"].mean()} h14\'e gittiğinde ssim{s1h6h14["ssim_first"].mean()}')
# Out:
# h6'nın h10'a gittiğindeki ssim0.6887994 h14'e gittiğinde ssim0.6895863999999999

# %%
s2h6h10=df_S2_h6[df_S2_h6["server"]=="h10"]
s2h6h14=df_S2_h6[df_S2_h6["server"]=="h14"]

print(f'h6\'nın h10\'a gittiğindeki ssim{s2h6h10["ssim_first"].mean()} h14\'e gittiğinde ssim{s2h6h14["ssim_first"].mean()}')
# Out:
# h6'nın h10'a gittiğindeki ssim0.942694 h14'e gittiğinde ssim0.9409677999999999

# %%
s3h6h10=df_S3_h6[df_S3_h6["server"]=="h10"]
s3h6h14=df_S3_h6[df_S3_h6["server"]=="h14"]

print(f'h6\'nın h10\'a gittiğindeki ssim{s3h6h10["ssim_first"].mean()} h14\'e gittiğinde ssim{s3h6h14["ssim_first"].mean()}')
# Out:
# h6'nın h10'a gittiğindeki ssim0.9528380000000001 h14'e gittiğinde ssim0.950852375
